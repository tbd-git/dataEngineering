# %%
listFruit=["apple", "banana", "cherry"]
blistFruit.remove("banana")
print(listFruit)
# Out:
# ['apple', 'cherry']

# %%
listFruit=["apple", "banana", "cherry"]
listRemovedA=[a.replace('a','') for a in listFruit]
print(listRemovedA)
# Out:
# ['pple', 'bnn', 'cherry']

# %%
import math
a=3.1245
math.ceil(a)
# Out:
# 4

# %%
listTest=[1,0,0,1,1,0,1]
# Move the zeros to the end of the list while maintaining the order of the other elements.
xZeros=[x for x in listTest if x==0]
xNonZeros=[x for x in listTest if x!=0]
listTest=xNonZeros+xZeros
print(listTest)
# Out:
# [1, 1, 1, 1, 0, 0, 0]
