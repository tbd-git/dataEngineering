# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("TestSpark").getOrCreate()
data = [("Alice", 34), ("Bob", 45), ("Cathy", 29)]
schema = ["Name", "Age"]
df = spark.createDataFrame(data, schema)
df.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[32], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName("TestSpark").getOrCreate()
#       3 data = [("Alice", 34), ("Bob", 45), ("Cathy", 29)]
#       4 schema = ["Name", "Age"]
#       5 df = spark.createDataFrame(data, schema)
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\pyspark\sql\session.py:562, in SparkSession.Builder.getOrCreate(self)
#     560     session = SparkSession(sc, options=self._options)
#     561 else:
# --> 562     module = SparkSession._get_j_spark_session_module(session._jvm)
#     563     module.applyModifiableSettings(session._jsparkSession, self._options)
#     564 return session
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\pyspark\sql\session.py:673, in SparkSession._get_j_spark_session_module(jvm)
#     671 @staticmethod
#     672 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 673     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
from pyspark.sql import Window
import pyspark.sql.functions  as F
dataEmp=[(1, "a", 1000), (2, "b", 2000), (3, "c", 3000), (4, "c", 4000)]
schemaEmp=["id", "name", "salary"]
df=spark.createDataFrame(dataEmp,schemaEmp)
windowSpec=Window.orderBy("id")
dfCumSal=df.withColumn("cumulativeSalary",F.sum("salary").over(windowSpec))
dfCumSal.show()
# Out:
# +---+----+------+----------------+
# | id|name|salary|cumulativeSalary|
# +---+----+------+----------------+
# |  1|   a|  1000|            1000|
# |  2|   b|  2000|            3000|
# |  3|   c|  3000|            6000|
# |  4|   c|  4000|           10000|
# +---+----+------+----------------+

# %%
dataMobile=[(1, "aaa", "apple"), (2, "bbb", "samsung"), (1, "aaa", "mi"), (3, "ccc", "redmi")]
schemaMobile=["id", "name", "dep"]
dfMobile=spark.createDataFrame(dataMobile, schemaMobile)
dfMobile.show()
# dfMobileJson=dfMobile.toJSON().collect()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[29], line 3
#       1 dataMobile=[(1, "aaa", "apple"), (2, "bbb", "samsung"), (1, "aaa", "mi"), (3, "ccc", "redmi")]
#       2 schemaMobile=["id", "name", "dep"]
# ----> 3 dfMobile=spark.createDataFrame(dataMobile, schemaMobile)
#       4 dfMobile.show()
#       5 # dfMobileJson=dfMobile.toJSON().collect()
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\pyspark\sql\session.py:1533, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1531 SparkSession._activeSession = self
#    1532 assert self._jvm is not None
# -> 1533 SparkSession._get_j_spark_session_class(self._jvm).setActiveSession(self._jsparkSession)
#    1534 if isinstance(data, DataFrame):
#    1535     raise PySparkTypeError(
#    1536         errorClass="INVALID_TYPE",
#    1537         messageParameters={"arg_name": "data", "arg_type": "DataFrame"},
#    1538     )
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\pyspark\sql\session.py:669, in SparkSession._get_j_spark_session_class(jvm)
#     667 @staticmethod
#     668 def _get_j_spark_session_class(jvm: "JVMView") -> "JavaClass":
# --> 669     return getattr(jvm, "org.apache.spark.sql.classic.SparkSession")
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File c:\Users\nsdeo\OneDrive\Documents\gitTest\dataEngineering\dataEngEnv\Lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
